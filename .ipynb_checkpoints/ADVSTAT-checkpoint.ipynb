# %%
class Word:
    def __init__(self, word):
        self.spamCount = 0
        self.hamCount = 0
        self.word = word
        self.MI = 0
        
    def addSpamCount(self):
        self.spamCount+=1
        
    def addHamCount(self):
        self.hamCount+=1    
    
    def setMI(self, mi):
        self.MI = mi
    
class wordList:
    def __init__(self):
        self.wordList = []
        
    def updateWordList(self, word, doctype):
        for currWord in self.wordList:
            if word is currWord.word and doctype is "ham":
                currWord.addHamCount()
                return 0
            elif word is currWord.word and doctype is "spam":
                currWord.addSpamCount()
                return 0
                
        newWord = Word(word)
        if doctype is "ham":
            newWord.addHamCount()
        elif doctype is "spam":
            newWord.addSpamCount()
        self.wordList.append(newWord)
        return 1
            
    def printWordList(self):
        for word in self.wordList:
            cnt = 0
            print(word.word + " " + "spam" + " " + str(word.spamCount))
            print(word.word + " " + "ham" + " " + str(word.hamCount))
            cnt += word.spamCount + word.hamCount
            print(str(cnt))

# %%
wordList = wordList()

# %%
print(wordList.wordList)
# Out:
# [<__main__.Word object at 0x0000017E0CA27160>, <__main__.Word object at 0x0000017E0CA27B38>, <__main__.Word object at 0x0000017E0CA27C88>, <__main__.Word object at 0x0000017E0CA27CC0>, <__main__.Word object at 0x0000017E0CA27D30>, <__main__.Word object at 0x0000017E0CA27A58>, <__main__.Word object at 0x0000017E0CA27A90>, <__main__.Word object at 0x0000017E0CA27AC8>, <__main__.Word object at 0x0000017E0CA27B70>, <__main__.Word object at 0x0000017E0CA27BA8>, <__main__.Word object at 0x0000017E0CA27F28>, <__main__.Word object at 0x0000017E0A9B9320>, <__main__.Word object at 0x0000017E0C9E4048>, <__main__.Word object at 0x0000017E0C9E4EF0>, <__main__.Word object at 0x0000017E0C9E40F0>, <__main__.Word object at 0x0000017E0C9E41D0>, <__main__.Word object at 0x0000017E0C9E4CF8>, <__main__.Word object at 0x0000017E0C9E45F8>, <__main__.Word object at 0x0000017E0C9E49B0>, <__main__.Word object at 0x0000017E0C9E4A90>, <__main__.Word object at 0x0000017E0C9E4D30>, <__main__.Word object at 0x0000017E0C9E4940>, <__main__.Word object at 0x0000017E0C9E4E48>, <__main__.Word object at 0x0000017E0C9E4710>, <__main__.Word object at 0x0000017E0C9E4DD8>, <__main__.Word object at 0x0000017E0C9E4400>, <__main__.Word object at 0x0000017E0C9E4B70>, <__main__.Word object at 0x0000017E0C9E4A58>, <__main__.Word object at 0x0000017E0C9E44E0>, <__main__.Word object at 0x0000017E0C9E4080>, <__main__.Word object at 0x0000017E0C9E4860>, <__main__.Word object at 0x0000017E0C9E4898>, <__main__.Word object at 0x0000017E0C9E4D68>, <__main__.Word object at 0x0000017E0C9E42E8>, <__main__.Word object at 0x0000017E0C9E4780>, <__main__.Word object at 0x0000017E0C9E47F0>, <__main__.Word object at 0x0000017E0C9E4128>, <__main__.Word object at 0x0000017E0C9E4AC8>, <__main__.Word object at 0x0000017E0C9E4240>, <__main__.Word object at 0x0000017E0C9E4978>, <__main__.Word object at 0x0000017E0C9E4470>, <__main__.Word object at 0x0000017E0C9E4EB8>, <__main__.Word object at 0x0000017E0C9E45C0>, <__main__.Word object at 0x0000017E0C9E4CC0>, <__main__.Word object at 0x0000017E0C9E4E80>, <__main__.Word object at 0x0000017E0C9E4E10>, <__main__.Word object at 0x0000017E0C9E48D0>, <__main__.Word object at 0x0000017E0C9E4FD0>, <__main__.Word object at 0x0000017E0C9E46D8>, <__main__.Word object at 0x0000017E0C9E4438>, <__main__.Word object at 0x0000017E0C9E4F60>, <__main__.Word object at 0x0000017E0C9E4630>, <__main__.Word object at 0x0000017E0C9E4278>, <__main__.Word object at 0x0000017E0C9E4C50>, <__main__.Word object at 0x0000017E0C9E47B8>, <__main__.Word object at 0x0000017E0C9E43C8>, <__main__.Word object at 0x0000017E0C9E4358>, <__main__.Word object at 0x0000017E0C9E4C88>, <__main__.Word object at 0x0000017E0C9E4160>, <__main__.Word object at 0x0000017E0C9E4668>, <__main__.Word object at 0x0000017E0C9E4DA0>, <__main__.Word object at 0x0000017E0C9E4518>, <__main__.Word object at 0x0000017E0C9E49E8>, <__main__.Word object at 0x0000017E0C9E4828>, <__main__.Word object at 0x0000017E0C9E4F28>, <__main__.Word object at 0x0000017E0C9E4550>, <__main__.Word object at 0x0000017E0C9E4208>, <__main__.Word object at 0x0000017E0C9E46A0>, <__main__.Word object at 0x0000017E0C9E42B0>, <__main__.Word object at 0x0000017E0C9E4908>, <__main__.Word object at 0x0000017E0C9E4320>, <__main__.Word object at 0x0000017E0C9E4198>, <__main__.Word object at 0x0000017E0C9E40B8>, <__main__.Word object at 0x0000017E0C9E4B38>, <__main__.Word object at 0x0000017E0C9E4588>, <__main__.Word object at 0x0000017E0C9E4BA8>, <__main__.Word object at 0x0000017E0C9E4C18>, <__main__.Word object at 0x0000017E0C9E4390>, <__main__.Word object at 0x0000017E0C9E4748>, <__main__.Word object at 0x0000017E0C9E4A20>, <__main__.Word object at 0x0000017E0B86A048>, <__main__.Word object at 0x0000017E0B86A0F0>, <__main__.Word object at 0x0000017E0B86A208>, <__main__.Word object at 0x0000017E0B86A240>, <__main__.Word object at 0x0000017E0B86A2E8>, <__main__.Word object at 0x0000017E0B86A3C8>, <__main__.Word object at 0x0000017E0B86A400 ...

# %%
import glob
import errno

numSpam = 0
numLegit = 0
numTotal = 0

print("HELLO")
for i in range (0,1):
    path = "emails/emails/lemm_stop/part0/*.txt"
    files = glob.glob(path)
    
    for name in files:
        checkedWordList = []
        if "spmsg" in name:
            numSpam += 1
        else:
            numLegit += 1
        numTotal += 1
        with open(name, 'r') as f:
                for line in f:
                    for word in line.split():
                        if "spmsg" in name and word not in checkedWordList:
                            wordList.updateWordList(word, "spam")
                            checkedWordList.append(word)
                        elif word not in checkedWordList:
                            wordList.updateWordList(word, "ham")
                            checkedWordList.append(word)

wordList.printWordList()
print(len(files))
# Out:
# HELLO
# Subject: spam 0
# Subject: ham 1
# 1
# re spam 0
# re ham 1
# 2
# : spam 5
# : ham 2
# 9
# 2 spam 3
# 2 ham 2
# 14
# . spam 6
# . ham 3
# 23
# 882 spam 0
# 882 ham 1
# 24
# s spam 2
# s ham 3
# 29
# - spam 4
# - ham 3
# 36
# > spam 0
# > ham 3
# 39
# np spam 0
# np ham 1
# 40
# deat spam 0
# deat ham 1
# 41
# sun spam 0
# sun ham 1
# 42
# , spam 5
# , ham 3
# 50
# 15 spam 0
# 15 ham 1
# 51
# dec spam 0
# dec ham 1
# 52
# 91 spam 0
# 91 ham 1
# 53
# 25 spam 0
# 25 ham 1
# 54
# est spam 0
# est ham 1
# 55
# michael spam 0
# michael ham 1
# 56
# < spam 0
# < ham 1
# 57
# mmorse spam 0
# mmorse ham 1
# 58
# @ spam 2
# @ ham 2
# 62
# vm1 spam 0
# vm1 ham 1
# 63
# yorku spam 0
# yorku ham 1
# 64
# ca spam 0
# ca ham 1
# 65
# subject spam 0
# subject ham 1
# 66
# 864 spam 0
# 864 ham 1
# 67
# query spam 0
# query ham 1
# 68
# wlodek spam 0
# wlodek ham 1
# 69
# zadrozny spam 0
# zadrozny ham 1
# 70
# ask spam 0
# ask ham 1
# 71
# " spam 3
# " ham 3
# 77
# anything spam 0
# anything ham 1
# 78
# interest spam 0
# interest ham 1
# 79
# construction spam 0
# construction ham 1
# 80
# second spam 0
# second ham 1
# 81
# much spam 0
# much ham 1
# 82
# relate spam 0
# relate ham 1
# 83
# consider spam 0
# consider ham 1
# 84
# form spam 0
# form ham 1
# 85
# discuss spam 0
# discuss ham 1
# 86
# list spam 0
# list ham 1
# 87
# late spam 0
# late ham 1
# 88
# reduplication spam 0
# reduplication ham 1
# 89
# ? spam 5
# ? ham 1
# 95
# logical spam 0
# logical ham 1
# 96
# sense spam 0
# sense ham 1
# 97
# john spam 0
# john ham 1
# 98
# mcnamara spam 0
# mcnamara ham 1
# 99
# name spam 0
# name ham 1
# 100
# tautologous spam 0
# tautologous ham 1
# 101
# thus spam 0
# thus ham 1
# 102
# level spam 0
# level ham 1
# 103
# indistinguishable spam 0
# indistinguishable ham 1
# 104
# here spam 0
# here ham 1
# 105
# ' spam 3
# ' ham 2
# 110
# support spam 0
# support ham 1
# 111
# those spam 0
# those ham 1
# 112
# logic-base spam 0
# logic-base ham 1
# 113
# semantics spam 0
# semantics ham 1
# 114
# irrelevant spam 0
# irrelevant ham 1
# 115
# natural spam 0
# natural ham 1
# 116
# language spam 0
# language ham 1
# 117
# supplies spam 0
# supplies ham 1
# 118
# value spam 0
# value ham 1
# 119
# attribute spam 0
# attribute ham 1
# 120
# follow spam 0
# follow ham 1
# 121
# fact spam 0
# fact ham 1
# 122
# name-attribute spam 0
# name-attribute ham 1
# 123
# relevant spam 0
# relevant ham 1
# 124
# entity spam 0
# entity ham 1
# 125
# chaim spam 0
# chaim ham 1
# 126
# shmendrik spam 0
# shmendrik ham 1
# 127
# false spam 0
# false ham 1
# 128
# tautology spam 0
# tautology ham 1
# 129
# ( spam 3
# ( ham 1
# 133
# either spam 0
# either ham 1
# 134
# ) spam 3
# ) ham 1
# 138
# Subject: spam 0
# Subject: ham 1
# 139
# np spam 0
# np ham 1
# 140
# + spam 0
# + ham 1
# 141
# discussion spam 0
# discussion ham 1
# 142
# remind spam 0
# remind ham 1
# 143
# ago spam 0
# ago ham 1
# 144
# read spam 0
# read ham 1
# 145
# source spam 0
# source ham 1
# 146
# forget spam 0
# forget ham 1
# 147
# critique spam 0
# critique ham 1
# 148
# newsmagazine spam 0
# newsmagazine ham 1
# 149
# unique spam 0
# unique ham 1
# web ham 0
# 734
# site spam 1
# site ham 0
# 735
# http spam 1
# http ham 0
# 736
# 138 spam 1
# 138 ham 0
# 737
# 27 spam 1
# 27 ham 0
# 738
# 44 spam 1
# 44 ham 0
# 739
# cearth spam 1
# cearth ham 0
# 740
# ca spam 1
# ca ham 0
# 741
# user spam 1
# user ham 0
# 742
# freewebsite spam 1
# freewebsite ham 0
# 743
# charge spam 1
# charge ham 0
# 744
# commitment spam 1
# commitment ham 0
# 745
# problem spam 1
# problem ham 0
# 746
# opportunity spam 1
# opportunity ham 0
# 747
# seeker spam 1
# seeker ham 0
# 748
# internet spam 1
# internet ham 0
# 749
# marketer spam 1
# marketer ham 0
# 750
# small spam 1
# small ham 0
# 751
# large spam 1
# large ham 0
# 752
# earn spam 1
# earn ham 0
# 753
# prosperous spam 1
# prosperous ham 0
# 754
# income spam 1
# income ham 0
# 755
# away spam 1
# away ham 0
# 756
# already spam 1
# already ham 0
# 757
# link spam 1
# link ham 0
# 758
# thousand spam 1
# thousand ham 0
# 759
# amaze spam 1
# amaze ham 0
# 760
# truly spam 1
# truly ham 0
# 761
# century spam 1
# century ham 0
# 762
# please spam 1
# please ham 0
# 763
# excuse spam 1
# excuse ham 0
# 764
# intrusion spam 1
# intrusion ham 0
# 765
# one spam 1
# one ham 0
# 766
# mail spam 1
# mail ham 0
# 767
# 9

# %%
import math

for word in wordList.wordList:
    mInformation = (word.spamCount/numTotal * math.log(numTotal * word.spamCount/((word.spamCount + word.hamCount) * numSpam)))
    mInformation += ((numSpam - word.spamCount)/numTotal * math.log(numTotal * (numSpam - word.spamCount)/((numSpam - word.spamCount + word.hamCount) * numSpam)))
    mInformation += (word.hamCount/numTotal * math.log(numTotal * word.hamCount/((word.spamCount + word.hamCount) * (word.hamCount + (numLegit)))))
    mInformation += ((numLegit - word.hamCount) / numTotal * math.log((numTotal * (numLegit - word.hamCount)) / ((word.hamCount + word.spamCount) * (numLegit))))
    print(word.word + " " + str(mInformation))
    #add MI
    word.setMI(mInformation)
# Out:
# Subject: 2.9120993215984834
# re 4.910946470352214
# 2 4.918594673342236
# . 1.8787175441087731
# 882 5.6584004405869965
# s 4.927774424916342
# - 2.5775360502652243
# > 4.077469467038293
# np 5.090049546231601
# deat 4.26521378621962
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-1793145f863b> in <module>()
#       2
#       3 for word in wordList.wordList:
# ----> 4     mInformation = (word.spamCount/numTotal * math.log(numTotal * word.spamCount/((word.spamCount + word.hamCount) * numSpam)))
#       5     mInformation += ((numSpam - word.spamCount)/numTotal * math.log(numTotal * (numSpam - word.spamCount)/((numSpam - word.spamCount + word.hamCount) * numSpam)))
#       6     mInformation += (word.hamCount/numTotal * math.log(numTotal * word.hamCount/((word.spamCount + word.hamCount) * (word.hamCount + (numLegit)))))
#
# ValueError: math domain error

# %% [markdown]
# # An Evaluation of Naive Bayesian Anti-Spam Filtering
# **Authors**: Ion Androutsopoulos, John Koutsias, Konstantinos V. Chandrinos, George Paliouras and Constantine D. Spyropoulos
#
# **Recreated by** : Amadora, Angelo and Choy, Seaver Mathew
#
# ---
# # 1 Introduction
#
# Unsolicited bulk e-mail which are sent to thousands  of recipients, is becoming common. Anyone with an e-mail will most likely have encountered or at least been sent these e-mails called "spam". Spam is annoying and sent by marketers in order to entice unsuspecting people into clicking links for many purposes unknown to them. Apart from wasting time, spam costs money to users
# with dial-up connections, wastes bandwidth, and may expose under-aged recipients to unsuitable (e.g.
# pornographic) content.
#
#
# There are many anti-spam filters available however, they rely mostly on manually constructed patternmatching. These systems need to be maintained in order to match a user's incoming message. This method requires both time and expertise. It would stand to reason that a system that would learn automatically to separate spam from legitimate massages would present significant changes.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline #for jupyter only... this will not work in pycharm
#Creating a Table

def table_row_generator(index,pd,label_type,l,a,avg_recall,avg_precision,avg_accuracy,avg_accuracy_base,avg_tcr):
    raw_data = {
        '#': index,
        'Filter Configuration': [label_type],
        'Lambda': [l], 
        'No. of attrib.': [a],
        'Spam Recall': [avg_recall],
        'Spam Precision': [avg_precision],
        'Weighted Accuracy': [avg_accuracy],
        'Baseline W. Acc': [avg_accuracy_base],
        'TCR': [avg_tcr]
    }
    return pd.DataFrame(raw_data, columns = ['#', 'Filter Configuration', 'Lambda', 'No. of attrib.', 'Spam Recall', 'Spam Precision', 'Weighted Accuracy', 'Baseline W. Acc', 'TCR'])
       
df_i = table_row_generator(1,pd,label_type[0],1,50,avg_recall,avg_precision,avg_accuracy,avg_accuracy_base,avg_tcr)
df_j = ...

df_table = pd.concat([df_i, df_j])
df_table.set_index('#', inplace=True) #para matangal yung index na paulit ulit
df_table = df_table.rename_axis(None) #para matangal si #
df_table

#Creating a Scatter Plot
#define colors if you want
colors = ['b', 'r', 'g', 'm']

#You can plot using 2 methods
#1.Direct 
plt.scatter(x_coord, y_coord, marker='o', color=colors[0])
#or
plt.scatter(x_coord_list, y_coord_list, marker='o', color=colors[0])
#2 Indirect with legend
scatter_1 = plt.scatter(x_coord, y_coord, marker='o', color=colors[0])
plt.legend((scatter_1,...),
           ('no lemmatizer, no stop-list', 'no lemmatizer, top-100 stop-list', 'with lemmatizer, no stop-list', 'with lemmatizer, top-100 stop-list'),
           scatterpoints=1,
           loc='lower right', #where the legend box will be located
           ncol=1, 
           fontsize=8 #font size of legend)

plt.xlabel('spam recall') #x field
plt.ylabel('spam precision') #y field

plt.grid() #if you want to show grid
plt.show() #display

#For Line Scatter Plot
#Use this to connect the lines of the same type
plt.plot(x_coord, y_coord, ls = "dotted", c=colors[3])
#or
plt.plot(x_coord_list, y_coord_list, ls = "dotted", c=colors[3])

#REMEMBER you can simply replace the x_coord or y_coord with a LIST, Python does the rest

# %%
import math
#Probability of spam, words is the vector of SIGNIFICANT words in the list obtained in the MI phase
def probabilityOfSpam(numSpam, numLegit, *words):
    #numSpam contains total number of spam
    #numLegit contains total number of legit
    #*words contains all the values of the probability of each signifacant word
    
    probSpam = math.log((numSpam/(numSpam+numLegit)),10) #the probability of getting a spam document
    accumulatedProbabilityOfWords = 1
    for num in list(words):
        accumulatedProbabilityOfWords *= num
    
    accumulatedProbabilityOfWords = math.log(accumulatedProbabilityOfWords,10)
    
    probLegit = math.log((numLegit/(numSpam+numLegit)),10)
    
    return (probSpam+accumulatedProbabilityOfWords)-probLegit
    
probabilityOfSpam(10,12,1,1,1,1)
# Out:
# -0.07918124604762483
